# %% [markdown]
# # K均值算法（K-means）聚类

# %% [markdown]
# ## 【关键词】K个种子，均值

# %% [markdown]
# ## 一、K-means算法原理

# %% [markdown]
# ### 聚类的概念：一种无监督的学习，事先不知道类别，自动将相似的对象归到同一个簇中。
#
# K-Means算法是一种聚类分析（cluster analysis）的算法，其主要是来计算数据聚集的算法，主要通过不断地取离种子点最近均值的算法。
#
# K-Means算法主要解决的问题如下图所示。我们可以看到，在图的左边有一些点，我们用肉眼可以看出来有四个点群，但是我们怎么通过计算机程序找出这几个点群来呢？于是就出现了我们的K-Means算法
#
# ![1.gif](attachment:1.gif)
#
# 这个算法其实很简单，如下图所示：
#
# ![2.jpg](attachment:2.jpg)
#
# 从上图中，我们可以看到，A，B，C，D，E是五个在图中点。而灰色的点是我们的种子点，也就是我们用来找点群的点。有两个种子点，所以K=2。
#
# 然后，K-Means的算法如下：
#
# 1. 随机在图中取K（这里K=2）个种子点。
# 2. 然后对图中的所有点求到这K个种子点的距离，假如点Pi离种子点Si最近，那么Pi属于Si点群。（上图中，我们可以看到A，B属于上面的种子点，C，D，E属于下面中部的种子点）
# 3. 接下来，我们要移动种子点到属于他的“点群”的中心。（见图上的第三步）
# 4. 然后重复第2）和第3）步，直到，种子点没有移动（我们可以看到图中的第四步上面的种子点聚合了A，B，C，下面的种子点聚合了D，E）。
#
# 这个算法很简单，重点说一下“求点群中心的算法”：欧氏距离（Euclidean Distance）：差的平方和的平方根
#
# ![3.gif](attachment:3.gif)

# %% [markdown]
# ### K-Means主要最重大的缺陷——都和初始值有关：
#
# K是事先给定的，这个K值的选定是非常难以估计的。很多时候，事先并不知道给定的数据集应该分成多少个类别才最合适。（ISODATA算法通过类的自动合并和分裂，得到较为合理的类型数目K）
#
# K-Means算法需要用初始随机种子点来搞，这个随机种子点太重要，不同的随机种子点会有得到完全不同的结果。（K-Means++算法可以用来解决这个问题，其可以有效地选择初始点）

# %% [markdown]
# ### 总结：K-Means算法步骤：
#
# 1. 从数据中选择k个对象作为初始聚类中心;
# 2. 计算每个聚类对象到聚类中心的距离来划分；
# 3. 再次计算每个聚类中心
# 4. 计算标准测度函数，直到达到最大迭代次数，则停止，否则，继续操作。
# 5. 确定最优的聚类中心

# %% [markdown]
# ### K-Means算法应用
#
# 看到这里，你会说，K-Means算法看来很简单，而且好像就是在玩坐标点，没什么真实用处。而且，这个算法缺陷很多，还不如人工呢。是的，前面的例子只是玩二维坐标点，的确没什么意思。但是你想一下下面的几个问题：
#
# 1）如果不是二维的，是多维的，如5维的，那么，就只能用计算机来计算了。
#
# 2）二维坐标点的X，Y 坐标，其实是一种向量，是一种数学抽象。现实世界中很多属性是可以抽象成向量的，比如，我们的年龄，我们的喜好，我们的商品，等等，能抽象成向量的目的就是可以让计算机知道某两个属性间的距离。如：我们认为，18岁的人离24岁的人的距离要比离12岁的距离要近，鞋子这个商品离衣服这个商品的距离要比电脑要近，等等。

# %% [markdown]
# ## 二、实战

# %% [markdown]
# 重要参数：
# - n_clusters：聚类的个数
#
# 重要属性：
# - cluster_centers_ : [n_clusters, n_features]的数组，表示聚类中心点的坐标
# - labels_ : 每个样本点的标签

# %% [markdown]
# ### 1、聚类实例

# %% [markdown]
# 导包，使用make_blobs生成随机点cluster_std

# %% [markdown]
# 建立模型,训练数据，并进行数据预测，使用相同数据

# %% [markdown]
# 无监督的情况下进行计算，预测
# 现在机器学习没有目标

# %% [markdown]
# 绘制图形，显示聚类结果kmeans.cluster_centers

# %% [markdown]
# ### 2、 实战，三问中国足球几多愁？

# %% [markdown]
# 导包，3D图像需导包：from mpl_toolkits.mplot3d import Axes3D
# 读取数据

# %% [markdown]
# 列名修改为："国家","2006世界杯","2010世界杯","2007亚洲杯"

# %% [markdown]
# 使用K-Means进行数据处理，对亚洲球队进行分组，分三组

# %% [markdown]
# for循环打印输出分组后的球队，argwhere()

# %% [markdown]
# 绘制三维立体图形,ax = plt.subplot(projection  = '3d')
# ax.scatter3D()

# %% [markdown]
# ### 3、聚类实践与常见错误

# %% [markdown]
# 导包，使用make_blobs创建样本点

# %% [markdown]
# 第一种错误，k值不合适，make_blobs默认中心点三个

# %% [markdown]
# 第二种错误,数据偏差
# trans = [[0.6,-0.6],[-0.4,0.8]]
# X2 = np.dot(X,trans)

# %% [markdown]
# 第三个错误:标准偏差不相同cluster_std

# %% [markdown]
# 第四个错误：样本数量不同

# %% [markdown]
# ### 4、K-Means图片颜色点分类

# %% [markdown]
# 导包from sklearn.metrics import pairwise_distances_argmin

# %% [markdown]
# 加载图片/创建模型/训练数据/获取labels

# %% [markdown]
# 使用pairwise_distances_argmin算法生成随机labels

# %% [markdown]
# 创造方法，重新合成图片

# %% [markdown]
# 数据可视化

# %% [markdown]
# ## 三、作业

# %% [markdown]
# ### 1、分析ex7data2.mat文件
#
# 找出最佳聚类数目，并画出聚类的中心点
#
# `
# from scipy.io import loadmat
# from sklearn.cluster import KMeans
# data = loadmat('../data/ex7data2.mat')
# X = data['X']
# X.shape
# `

# %% [markdown]
# ### 2、图片压缩

# %% [markdown]
# 使用聚类压缩图片
#
# `
# img = plt.imread('../data/bird_small.png')
# img_shape = img.shape
# img_shape
# `

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
# png (0~1颜色)
# jpg (0~255颜色)

# %%
bird = plt.imread('../data/bird_small.png')
bird.shape
# Out:
# (128, 128, 3)

# %%
plt.imshow(bird)

# %%
bird_data = bird.reshape((-1,3))
# 16384个像素点--->4类，代表图片中最重要的颜色值
bird_data.shape
# Out:
# (16384, 3)

# %%
from pandas import DataFrame

# %%
df = DataFrame(bird_data)
# 查看是否有重复的数据
16384-df.duplicated().sum()
# 13930个不同的颜色值的点
# Out:
# 13930

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=64)

# %%
# 无监督学习
kmeans.fit(bird_data)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=64, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
# 进行预测，获取label值
y_ = kmeans.predict(bird_data)
y_
# Out:
# array([26, 16, 26, ..., 36, 36, 36], dtype=int32)

# %%
# 获取聚类的中心点
# 中心点------>颜色值
colors = kmeans.cluster_centers_
colors
# Out:
# array([[ 0.95049334,  0.64276874,  0.27664167],
#        [ 0.1140826 ,  0.12258738,  0.11289214],
#        [ 0.983105  ,  0.87464708,  0.79774231],
#        [ 0.44416028,  0.42287177,  0.38146392],
#        [ 0.37889439,  0.27442545,  0.24283427],
#        [ 0.68376952,  0.58476281,  0.58576465],
#        [ 0.79969168,  0.67729074,  0.44339311],
#        [ 0.78215212,  0.59754908,  0.28407493],
#        [ 0.67280281,  0.46374473,  0.18229932],
#        [ 0.51900762,  0.66190475,  0.87619054],
#        [ 0.17698741,  0.18296957,  0.18442576],
#        [ 0.94490445,  0.8340987 ,  0.50779909],
#        [ 0.98947334,  0.96879494,  0.78798062],
#        [ 0.06587324,  0.07163015,  0.06154436],
#        [ 0.50950384,  0.40828329,  0.26160461],
#        [ 0.30767107,  0.34623325,  0.46542829],
#        [ 0.86124265,  0.74013829,  0.48707801],
#        [ 0.63857979,  0.43754637,  0.38068363],
#        [ 0.84034312,  0.73305535,  0.74760002],
#        [ 0.69042021,  0.7735014 ,  0.77613449],
#        [ 0.70473516,  0.6413551 ,  0.4948616 ],
#        [ 0.53896898,  0.37465265,  0.13774841],
#        [ 0.44498491,  0.53171194,  0.76670432],
#        [ 0.26634461,  0.27095556,  0.28949139],
#        [ 0.9763217 ,  0.93504608,  0.70052373],
#        [ 0.87672019,  0.49187165,  0.27490196],
#        [ 0.87027985,  0.7216332 ,  0.40984654],
#        [ 0.97514915,  0.69083536,  0.55528569],
#        [ 0.34795675,  0.41550303,  0.63676012],
#        [ 0.80392158,  0.94332218,  0.94480211],
#        [ 0.64413655,  0.56398946,  0.41764703],
#        [ 0.62283939,  0.51301861,  0.50833952],
#        [ 0.43608701,  0.34899813,  0.20531455],
#        [ 0.82958317,  0.66055918,  0.35341942],
#        [ 0.97927511,  0.76693869,  0.65285969],
#        [ 0.54159284,  0.47163579,  0.44046476],
#        [ 0.23363984,  0.17575049,  0.12693076],
#        [ 0.6851036 ,  0.55847979,  0.31108633],
#        [ 0.78305727,  0.70350564,  0.54616725],
#        [ 0.86843294,  0.82830811,  0.82368481],
#        [ 0.95694327,  0.89767575,  0.60323447],
#        [ 0.44799584,  0.33463475,  0.30444214],
#        [ 0.98311847,  0.72037375,  0.4227635 ],
#        [ 0.74126047,  0.61328286,  0.3850587 ],
#        [ 0.99042916,  0.97762358,  0.88339347],
#        [ 0.53859842,  0.5778867 ,  0.55791569],
#        [ 0.53030401,  0.38659614,  0.36638656],
#        [ 0.59357047,  0.6568172 ,  0.681669  ],
#        [ 0.93893111,  0.59122884,  0.4008382 ],
#        [ 0.91593361,  0.52997202,  0.13979244],
#        [ 0.14059696,  0.15002683,  0.14227471],
#        [ 0.2291618 ,  0.22635065,  0.22678462],
#        [ 0.32651332,  0.33393008,  0.34426683],
#        [ 0.44551086,  0.29158932,  0.12729628],
#        [ 0.97845125,  0.8238973 ,  0.71644211],
#        [ 0.58280325,  0.49254903,  0.31299928],
#        [ 0.72161674,  0.52471554,  0.22482049],
#        [ 0.77087116,  0.66213882,  0.66414034],
#        [ 0.08965462,  0.0969986 ,  0.08622462],
#        [ 0.85321403,  0.78202808,  0.5997144 ],
#        [ 0.62623215,  0.82437742,  0.93879187],
#        [ 0.32712597,  0.22571023,  0.16514637],
#        [ 0.42951232,  0.47586727,  0.49798894],
#        [ 0.59004277,  0.44029695,  0.18471736]], dtype=float32)

# %%
a = np.array([1,10,-5])
b = np.array([0,0,2,2,1,0])
a[b]
# Out:
# array([ 1,  1, -5, -5, 10,  1])

# %%
plt.imshow(bird)

# %%
# colors 4个主要的颜色值
# y_预测出来的索引值，代表分类
bird_new = colors[y_].reshape((128,128,3))

plt.imshow(bird_new)

plt.imsave('../data/bird_small_new.png',bird_new)
