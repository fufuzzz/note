# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import DataFrame
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### 五、练习
# 1、使用多种方法对boston数据集进行回归，画出回归图像，并比较多种回归方法的效果

# %%
from sklearn.datasets import load_boston
boston = load_boston()
data = boston.data
target = boston.target
feature_names = boston.feature_names

# %%
df = DataFrame(data=data, columns=feature_names)
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2)

# %%
knn = KNeighborsRegressor()
knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
knn.score(X_test, y_test)
# Out:
# 0.4267301207022345

# %%
knn.score(X_train, y_train)
# Out:
# 0.7030729857140253

# %%
linear = LinearRegression()
linear.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
linear.score(X_test, y_test)
# Out:
# 0.6741871407288293

# %%
linear.score(X_train, y_train)
# Out:
# 0.7567799762133971

# %%
poly2 = PolynomialFeatures()
X_train_poly2 = poly2.fit_transform(X_train)
linear_poly2 = LinearRegression()
linear_poly2.fit(X_train_poly2, y_train)
# Out:
# LinearRegression()

# %%
X_test_poly2 = poly2.transform(X_test)
linear_poly2.score(X_test_poly2, y_test)
# Out:
# 0.8327445718083628

# %%
linear_poly2.score(X_train_poly2, y_train)
# Out:
# 0.9263032126690861

# %%
plt.figure(figsize=(3*10,11*5))
for i, col in enumerate(feature_names,1):
    X_train = df[[col]]
    X_test = np.linspace(X_train.min(), X_train.max(),100).reshape(-1,1)
    
    knn = KNeighborsRegressor()
    knn.fit(X_train, target)
    yk_ = knn.predict(X_test)
    
    linear = LinearRegression()
    linear.fit(X_train, target)
    y_ = linear.predict(X_test)
    
    poly2 = PolynomialFeatures()
    X_train_poly2 = poly2.fit_transform(X_train)
    linear_poly2 = LinearRegression()    
    linear_poly2.fit(X_train_poly2, target)
    X_test_poly2 = poly2.fit_transform(X_test)
    y2 = linear_poly2.predict(X_test_poly2)
    
    poly3 = PolynomialFeatures(degree=3)
    X_train_poly3 = poly3.fit_transform(X_train)
    linear_poly3 = LinearRegression()
    linear_poly3.fit(X_train_poly3, target)
    X_test_poly3 = poly3.fit_transform(X_test)
    y3 = linear_poly3.predict(X_test_poly3)
    
    
    axes = plt.subplot(5,3,i)
    axes.scatter(X_train, target, c='#CEF6E3')
    axes.plot(X_test,yk_,c='b')
    axes.plot(X_test,y_,c='r')
    axes.plot(X_test,y2,c='g')
    axes.plot(X_test,y3,c='y')
    score = linear.score(X_train, target)
    score2 = linear_poly2.score(X_train_poly2, target)
    score3 = linear_poly3.score(X_train_poly3, target)
    axes.set_title(f'{col}\n score:{score}\n score2:{score2}\n score3:{score3}',fontdict=dict(size=20,color='r'))

# %% [markdown]
# 2、预测鲍鱼的年龄
# abalone.txt

# %%
abalone = pd.read_csv('./data/abalone.txt', sep='\t', header=None)
abalone
# Out:
#       0      1      2      3       4       5       6       7   8
# 0     1  0.455  0.365  0.095  0.5140  0.2245  0.1010  0.1500  15
# 1     1  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.0700   7
# 2    -1  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.2100   9
# 3     1  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.1550  10
# 4     0  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.0550   7
# ...  ..    ...    ...    ...     ...     ...     ...     ...  ..
# 4172 -1  0.565  0.450  0.165  0.8870  0.3700  0.2390  0.2490  11
# 4173  1  0.590  0.440  0.135  0.9660  0.4390  0.2145  0.2605  10
# 4174  1  0.600  0.475  0.205  1.1760  0.5255  0.2875  0.3080   9
# 4175 -1  0.625  0.485  0.150  1.0945  0.5310  0.2610  0.2960  10
# 4176  1  0.710  0.555  0.195  1.9485  0.9455  0.3765  0.4950  12
#
# [4177 rows x 9 columns]

# %%
abalone.columns = ['Sex',
                    'Length',
                    'Diameter',
                    'Height',
                    'Whole weight',
                    'Shucked weight',
                    'Viscera weight',
                    'Shell weight',
                    'Rings']

# %%
abalone
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       1   0.455     0.365   0.095        0.5140          0.2245
# 1       1   0.350     0.265   0.090        0.2255          0.0995
# 2      -1   0.530     0.420   0.135        0.6770          0.2565
# 3       1   0.440     0.365   0.125        0.5160          0.2155
# 4       0   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172   -1   0.565     0.450   0.165        0.8870          0.3700
# 4173    1   0.590     0.440   0.135        0.9660          0.4390
# 4174    1   0.600     0.475   0.205        1.1760          0.5255
# 4175   -1   0.625     0.485   0.150        1.0945          0.5310
# 4176    1   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
abalone.describe()  # 发现异常值!!!!!!  height 有个 比平均高度高了1米
# Out:
#                Sex       Length     Diameter       Height  Whole weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean      0.052909     0.523992     0.407881     0.139516      0.828742
# std       0.822240     0.120093     0.099240     0.041827      0.490389
# min      -1.000000     0.075000     0.055000     0.000000      0.002000
# 25%      -1.000000     0.450000     0.350000     0.115000      0.441500
# 50%       0.000000     0.545000     0.425000     0.140000      0.799500
# 75%       1.000000     0.615000     0.480000     0.165000      1.153000
# max       1.000000     0.815000     0.650000     1.130000      2.825500
#
#        Shucked weight  Viscera weight  Shell weight        Rings
# count     4177.000000     4177.000000   4177.000000  4177.000000
# mean         0.359367        0.180594      0.238831     9.933684
# std          0.221963        0.109614      0.139203     3.224169
# min          0.001000        0.000500      0.001500     1.000000
# 25%          0.186000        0.093500      0.130000     8.000000
# 50%          0.336000        0.171000      0.234000     9.000000
# 75%          0.502000        0.253000      0.329000    11.000000
# max          1.488000        0.760000      1.005000    29.000000

# %%
# 搞定异常值
abalone.loc[(abalone['Height']>3 * abalone['Height'].mean()), 'Height'] = abalone['Height'].mean()

# %%
abalone.describe()  # 检查是否填充搞定异常值
# Out:
#                Sex       Length     Diameter       Height  Whole weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean      0.052909     0.523992     0.407881     0.139189      0.828742
# std       0.822240     0.120093     0.099240     0.038480      0.490389
# min      -1.000000     0.075000     0.055000     0.000000      0.002000
# 25%      -1.000000     0.450000     0.350000     0.115000      0.441500
# 50%       0.000000     0.545000     0.425000     0.140000      0.799500
# 75%       1.000000     0.615000     0.480000     0.165000      1.153000
# max       1.000000     0.815000     0.650000     0.250000      2.825500
#
#        Shucked weight  Viscera weight  Shell weight        Rings
# count     4177.000000     4177.000000   4177.000000  4177.000000
# mean         0.359367        0.180594      0.238831     9.933684
# std          0.221963        0.109614      0.139203     3.224169
# min          0.001000        0.000500      0.001500     1.000000
# 25%          0.186000        0.093500      0.130000     8.000000
# 50%          0.336000        0.171000      0.234000     9.000000
# 75%          0.502000        0.253000      0.329000    11.000000
# max          1.488000        0.760000      1.005000    29.000000

# %%
data = abalone.iloc[:, 1:-1].values.copy()
target = abalone.iloc[:,-1].values.copy()
target
# Out:
# array([15,  7,  9, ...,  9, 10, 12], dtype=int64)

# %%
abalone[['Height']].max()
# Out:
# Height    0.25
# dtype: float64

# %%
plt.figure(figsize=(2 * 6, 7 * 5))
for i, col in enumerate(abalone.columns[0:-1], 1):
    X_train = abalone[[col]]
    X_test = np.linspace(X_train.min(), X_train.max(),100).reshape(-1,1)
    
    linear = LinearRegression()
    linear.fit(X_train, target)
    y_ = linear.predict(X_test)
    
#     axes.set_title(col +':' +str(score))
    
    
    poly2 = PolynomialFeatures()
    X_train_poly2 = poly2.fit_transform(X_train)    
    X_test_poly2 = poly2.fit_transform(X_test)
    linear_poly2 = LinearRegression()
    linear_poly2.fit(X_train_poly2, target)
    y2_ = linear_poly2.predict(X_test_poly2)
    
    
    poly3 = PolynomialFeatures(degree=3)
    X_train_poly3 = poly3.fit_transform(X_train)    
    X_test_poly3 = poly3.fit_transform(X_test)
    linear_poly3 = LinearRegression()
    linear_poly3.fit(X_train_poly3, target)
    y3_ = linear_poly3.predict(X_test_poly3)
    
    axes = plt.subplot(5,2,i)
    axes.scatter(X_train, target, c='#CEF6E3')
    axes.plot(X_test, y_, c='r')
    axes.plot(X_test, y2_, c='g')
    axes.plot(X_test, y3_,c='y')
    
    score = linear.score(X_train, target)
    score2 = linear_poly2.score(X_train_poly2, target)
    score3 = linear_poly3.score(X_train_poly3, target)
    
    axes.set_title(f'feature:{col}\n score:{score}\n score2:{score2}\n score3:{score3}',fontdict=dict(size=10,color='r'))

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2)

# %%
poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_train)

# %%
linear = LinearRegression()
linear.fit(X_train_poly, y_train)
# Out:
# LinearRegression()

# %%
X_test_poly = poly.fit_transform(X_test)
linear.predict(X_test_poly)+1.5
# Out:
# array([12.03468578,  8.78426822, 12.96918116, 11.80932909,  9.988304  ,
#        11.31532081, 12.45522491, 11.20530868, 10.30743832,  9.69229756,
#         9.49115646, 13.17888552, 10.07194482, 10.05495497, 10.01249255,
#        11.86211296, 10.02774623,  9.90485368, 10.5763462 , 12.9847944 ,
#         9.34016027, 11.22531675,  7.93174982,  8.56310453, 11.69156674,
#        14.11654688, 10.79862845, 13.14955266,  5.64200834, 10.33111331,
#        13.47768749, 10.68323232,  9.89515   ,  8.81855339, 13.32743279,
#        10.04225846, 12.40712499, 13.22891645,  9.66834621,  9.1456572 ,
#         5.08122058,  9.77608109, 10.53716374,  9.70865764, 12.27219726,
#        10.18009541, 10.97826537, 14.52213662, 10.82784099, 11.42953799,
#         7.98415834, 12.70452675, 15.79916378, 11.38019424, 14.06475385,
#        10.00023067, 11.6585704 ,  9.87849142, 12.53383564, 13.31922265,
#        10.17777408, 11.42406165, 13.29578129,  8.49522814,  7.91431981,
#         9.94927635, 19.48292765,  8.27929537,  8.54761397, 13.07630729,
#         9.18589742, 13.96793386, 11.27302099, 12.01164735,  8.44249719,
#        11.14504495,  8.54705703, 18.44042578, 10.36295403,  8.75046071,
#        10.66567706, 10.04859829, 13.19823478, 11.18616929, 12.5886117 ,
#        21.52924033,  9.25627928, 11.90318445, 11.23182595, 10.76310684,
#        11.72731346, 11.04279481, 13.8147112 , 11.28860822, 15.05407254,
#        11.8244697 , 10.62832649, 12.07866161, 17.13022587,  9.13523559,
#        12.78449506, 11.31361904, 12.32897551, 14.70865671, 12.67363541,
#        12.38870867,  5.31232853, 11.46029929,  9.4686266 , 14.13825246,
#        10.33377328, 11.33144153, 13.65659435, 12.41701175, 13.30193123,
#        16.77017506, 11.94984279, 11.27552782, 10.88114202, 11.37861982,
#        10.24375232, 14.88856184,  9.47360353, 16.35708518, 10.93819045,
#        10.64863709, 11.49631578,  7.72332095, 15.0949351 , 15.03257889,
#        10.41908475, 10.04768223,  9.09266287, 11.78807363,  7.40842996,
#        11.70666357, 11.26750666,  6.41021861, 13.39324867, 13.6167985 ,
#        11.08428008, 10.83488799,  9.31928951, 11.06956097,  9.83892826,
#        13.60192184, 14.28677474,  7.4071484 , 11.57886074, 14.22547792,
#         8.91947698, 11.11764516, 12.56016948, 12.54854357, 10.15231219,
#         9.41299725,  7.7367258 , 12.12830747, 13.93521868, 12.93661011,
#        12.25763271, 11.80465746, 13.29242729, 13.0070997 , 12.30429561,
#        12.20816672, 11.4680266 , 10.29501932, 13.29768316, 13.32609503,
#        11.96183812,  8.84181033,  8.346263  ,  9.77254311, 11.378891  ,
#         6.79351027,  8.82713067, 10.73659705, 10.3124294 , 12.97608414,
#        10.16489316,  7.96248058,  9.12515113,  7.3904724 , 18.13008584,
#        10.49569381, 14.41516881,  9.58840409,  5.47449782, 12.05824194,
#        10.40445421, 11.95762344, 12.23167437,  9.83591903, 10.73185604,
#        12.36473684, 16.47841304,  5.90196153,  8.07387931,  7.54169382,
#        11.99276561, 10.94027682,  5.77232497, 15.55431204, 13.38525412,
#        11.04052199,  9.86130643, 10.96093688,  9.03757464, 11.55671427,
#         8.36906388,  4.90601821, 15.1547405 , 11.54276251, 17.43442834,
#        12.15748512, 15.2768287 , 14.18200199, 11.41871198,  9.64092058,
#        10.7236813 , 14.152938  ,  9.95707741, 12.36121285, 12.81759814,
#         7.13370002,  8.76742583, 11.05779949, 15.9032583 , 11.58953598,
#        14.51986844,  9.52973934, 12.33441565,  9.3249756 , 11.89748044,
#        13.411125  , 10.75630181, 10.77342279, 10.37009904,  7.76704717,
#        17.67571173, 11.7739798 ,  8.73828798, 12.22398635, 11.63242908,
#        12.238564  , 11.75785987, 12.85257765,  9.41301984,  9.92059177,
#         8.84237829, 12.28945915, 10.91988702, 11.21392794,  9.86129755,
#        10.51376865, 12.37079522, 12.46187832, 11.46069306, 10.33283396,
#        12.49052155, 10.15061774,  9.084075  ,  9.7325027 , 13.20160984,
#        11.62889607, 12.38389047, 10.24466783, 14.20778829, 10.35404934,
#        12.05475018, 19.74429096, 11.95368133, 13.20458129,  9.60200203,
#        14.10834522, 11.03906426,  9.97722295, 12.84580417, 12.16856402,
#        13.76863421, 10.31730527, 11.61962233,  9.55624728,  9.9342654 ,
#         8.67491559, 12.86631813, 11.72494946, 14.35484077, 10.21566072,
#         7.54990297, 15.39711399, 10.69010164,  8.93980591, 12.74726194,
#        12.0427982 , 10.64882907, 10.12464835, 10.82907415,  9.54604538,
#         9.59332538, 10.02215629,  9.99263068,  7.8484427 , 12.58797089,
#        12.60309979, 12.99517991, 16.34823466, 11.33061683, 14.23276972,
#        16.45773693, 14.21848523, 12.53617135, 16.63708482,  8.86184309,
#        11.4867518 , 14.51576478, 18.95617112, 10.5713208 , 12.26853659,
#        13.75167355, 15.69662624,  8.00390879, 12.38158946, 11.89988706,
#        12.2954801 , 10.12238962,  8.4373602 , 10.81094845, 10.41058033,
#         9.28536171, 12.62973454, 13.33395852, 13.15581561,  7.72727239,
#        10.66529399, 11.31151935,  9.25853298,  8.70166201,  8.9066671 ,
#        12.04179578,  8.56121596, 10.77171192, 12.1661588 ,  9.97502029,
#        10.80261416, 10.55408189, 11.87402263, 10.45279932, 12.51753098,
#        11.72197164, 10.65116623,  9.15379892, 10.65533481,  8.40222017,
#         7.57740125,  9.80384076,  3.13390587,  8.07660704,  8.99763937,
#        15.55813645,  8.9976154 ,  2.0465391 , 13.19653468, 10.10193968,
#         9.51433944, 13.41419733, 13.71237731, 12.97955057, 12.77186105,
#        10.49987574,  8.88267199, 13.4854232 , 13.11439011, 13.02952306,
#        11.9725354 , 10.07197871,  6.95299519, 10.40383454, 13.51932246,
#        12.30517389, 11.48841641,  7.73165486, 21.00713857, 14.92240703,
#        12.79880097, 11.22314005, 11.26262614, 11.06892555,  7.97785126,
#        13.62743685, 11.72149423,  6.17109684, 12.55912693,  8.12199695,
#        15.67115405,  4.8093988 , 11.87978796,  9.75817763,  8.43446524,
#         7.33888755, 10.76254034, 14.64619712, 12.20370252,  6.24554462,
#        14.85469945, 11.07219475,  8.08269513, 12.56511309, 11.37560188,
#        10.00625504, 10.80447605,  9.52256559,  8.82961026, 11.24562805,
#        10.79163124,  9.25143303, 14.90063865, 12.21415585, 14.08659111,
#        13.64710974, 11.59685984, 11.45929064, 19.30490562,  9.70423838,
#        13.070507  , 10.79658757,  9.9331254 ,  9.84818447, 12.3154703 ,
#        13.49081089, 14.23932668, 10.20503914,  9.24167264,  7.93530241,
#         8.88151795, 13.34971437, 13.04839107,  9.2569719 ,  8.47362498,
#        14.18186339, 10.415771  , 14.07676413,  9.45793489,  8.49316181,
#        11.54955119,  9.57208812, 15.30835897, 12.31952243,  9.65034732,
#         9.48021574, 10.63493673, 15.96566141, 15.21088333, 10.7955665 ,
#        11.17825972,  8.15442514,  8.78224538,  9.71543883, 13.81784176,
#         9.86584783, 11.72701682, 12.37627646, 10.09060751, 10.21220406,
#        11.66389133, 10.56686991, 10.66554787, 11.52654205, 13.27425795,
#        13.05211096, 12.13401208,  9.87188939, 13.47542905,  7.70415764,
#        11.63618897, 12.4736401 ,  7.57413523, 11.02782549, 13.57286147,
#        14.1731858 , 10.26489924, 11.94691651, 14.34017733, 10.64944518,
#        10.25956527, 10.50803109, 12.15419121, 10.38364695, 13.08515544,
#         6.85101393, 13.04892522, 12.92847493,  7.37654641,  7.94711884,
#        10.50925973, 11.92968176, 11.61552167,  9.89286397,  9.62364439,
#        15.79435834, 10.44038492, 11.83777615,  9.14774375,  8.50083368,
#        11.6474812 , 14.83769111,  9.22589525,  9.90024982, 15.89114889,
#         9.79287311, 14.33565983, 10.63466726, 11.61414862, 11.18107869,
#        13.21280253, 15.32935651,  9.91802418,  8.20897643, 13.48847912,
#        12.10242902,  7.06454985, 10.91078214, 13.08815838, 12.64180677,
#        10.8841899 , 10.72789142, 12.11137557, 18.23556989,  8.89957541,
#        11.53705722, 11.24058714, 12.3156672 , 12.63295455,  7.42811388,
#        12.6725091 ,  9.55139259, 12.51065808, 17.34436404,  8.91842907,
#         9.97115295, 12.09188639, 10.88201019, 16.79829403, 13.65947879,
#         9.87049254,  9.90658406, 11.64541162, 11.39445232, 11.06575009,
#        12.45978272,  9.99932747, 12.01569126, 10.2889904 , 11.13596722,
#        11.37750449,  8.60125563, 11.01462714, 11.23206108,  8.37051481,
#        10.88924555, 11.46849249, 12.23399156,  8.59981246,  6.99883546,
#         9.94785426, 11.6664535 , 10.32474148, 10.70346602,  7.59774602,
#        13.9939455 ,  9.53223672, 13.26136613, 15.40150589, 10.26412944,
#        11.9244751 , 12.97007267, 11.65233068, 11.59544024, 11.09870652,
#        13.21537159, 11.37562863, 13.97151285, 10.96901563,  7.12890438,
#        12.52207117, 10.03221583, 12.52157013, 11.94536267,  7.18399339,
#         7.83220522, 10.98045482, 12.41518886, 11.01388818,  9.42918941,
#        15.18107089,  9.98045374, 12.70936097, 11.28150112, 15.88928084,
#        14.57585834, 13.73387842, 10.77380174, 13.77592465, 16.61953468,
#         9.41378294,  9.71712022, 10.90055224, 10.96725352, 11.17157262,
#        11.07321583, 13.631854  , 11.04663534,  9.47793378,  9.97984937,
#        11.29405678, 12.32520518, 12.45578973, 12.3251448 , 14.59599961,
#        14.70333385,  7.18769045, 12.61054106, 10.62666061, 10.37713264,
#        10.6976598 ,  6.15915911, 14.1442397 ,  8.5396517 , 10.73178281,
#        10.04593869, 12.10372482, 12.10177773,  8.26754376, 13.73447022,
#         6.97212359, 12.1713449 , 11.92415662, 18.61220228,  6.06948176,
#        14.21871825,  8.38840881, 12.36244035, 11.13562062,  8.27743518,
#         9.92783116, 11.96341538, 10.41067872, 11.94477059, 11.85368508,
#        12.29390604, 11.06883181, 13.28745291, 12.40352063, 10.789399  ,
#        12.25690625, 16.49061727,  4.46977103, 11.03209176, 11.97374067,
#        12.8411223 , 12.59581151, 16.44276994, 10.05499732, 11.94661221,
#        11.08935837, 14.60274153, 13.2214934 , 13.46067303, 11.35376635,
#        11.99996709,  9.72180379,  9.87398662, 14.65984976, 11.21127672,
#        15.45736063, 11.53005877,  8.36088113, 10.40578521, 11.53787067,
#        11.26562724, 12.52029766, 10.12873311, 12.88342236, 11.29041109,
#         9.20273807,  9.59622855, 12.66119573, 12.57516341, 12.55278662,
#        14.13365465, 12.81545876, 10.14337478,  9.86764614, 10.06155247,
#        11.64690745, 15.84450346,  9.94749994, 10.55714107,  7.83324058,
#         8.91873754, 11.04053402, 12.62597885, 10.16321961, 13.8405681 ,
#        12.52428838, 11.36315878, 11.81017088, 11.51348223, 11.20954497,
#        11.17055478,  9.49589735, 11.01312797, 13.25104197, 10.59530589,
#         9.98467846, 10.77024567, 12.89221595, 10.42182133,  9.50671964,
#        15.99746024,  8.48027398, 11.03459978, 12.56645818, 17.86829413,
#         9.10560577, 10.97633154, 12.77786657, 11.77327555, 11.09296404,
#        11.65003617, 12.56773543,  8.8539272 ,  8.9753854 , 13.8205312 ,
#        11.5542647 ,  9.50704139,  9.66461826, 12.52879559, 10.18039227,
#        11.71774222, 12.43842018, 10.46326392, 12.76313292, 10.48806245,
#        10.45940194, 12.65997363, 13.02870933, 10.68560892,  9.13696773,
#         8.15036863,  8.78753137, 12.35335626, 15.52479924, 15.9715244 ,
#        12.95876219,  8.96122159, 10.20438585, 13.53363196, 12.33684216,
#        13.35296394,  9.32285687, 12.39549444, 12.51822989,  9.17583387,
#         8.60923121, 12.66651453,  9.13969229,  5.96576111, 12.58695845,
#        12.19231121,  9.70313842,  7.26770705, 10.19218686, 13.01271752,
#        13.73514178, 14.27498901, 10.85998006, 12.16497596, 12.94857023,
#        13.60360665, 13.68408719, 12.15381056,  9.74046404, 10.73784709,
#        13.35283684, 13.65394422, 15.60281868,  8.78318348,  9.87481884,
#        12.21645089, 13.34828125,  8.18762476, 11.64584793, 11.74992583,
#        12.06139408,  5.9424488 , 11.09376173,  7.58734177, 16.1682735 ,
#        12.07272821, 15.49240277, 11.72029873, 14.26974927, 13.2717849 ,
#        16.56280989,  9.07568089,  9.25187078,  6.0265601 , 10.50878444,
#         8.11627268, 11.03965166, 13.32015856, 14.83342835, 10.97303634,
#        11.00029773, 11.74207556,  6.79968752,  9.87737647, 15.13205495,
#         8.33879209, 10.55095034, 13.61362444, 11.36807551,  8.60051553,
#         4.83906001, 10.94172612, 11.36513961, 20.01669413, 10.62981863,
#        18.72011298,  8.88929245, 12.98443421, 11.76532651, 10.21922688,
#        10.62258385])

# %%
linear.score(X_test_poly, y_test)
# Out:
# 0.5468716531092721

# %%
linear.score(X_train_poly, y_train)
# Out:
# 0.5861258385158892
