# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import xlrd

# %% [markdown]
# ### pandas提供了一些用于将表格型数据读取为DataFrame对象的函数，期中read_csv和read_table这两个使用最多

# %%
# pandas读的文件, 必须是结构化的文件

# %% [markdown]
# 使用read_csv将其读入

# %%
pd.read_csv('./data/SMSSpamCollection', sep='\t', header=None)
# Out:
#          0                                                  1
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %% [markdown]
# 使用read_table读取

# %%
pd.read_excel('./data/产品分类表.xlsx')
# Out:
# c:\users\ause\desktop\python2101\2101\env\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Your version of xlrd is 1.2.0. In xlrd >= 2.0, only the xls format is supported. As a result, the openpyxl engine will be used if it is installed and the engine argument is not specified. Install openpyxl instead.
#   """Entry point for launching an IPython kernel.
#     产品ID       产品名称    产品子分类  产品分类  产品分类ID
# 0    743      山地自行车    山地自行车   自行车       1
# 1    745    山地自行车车架  山地自行车车架    配件       3
# 2    709      公路自行车    公路自行车   自行车       1
# 3    731         帽子       帽子    服装       2
# 4    759      长袖运动衫      运动衫    服装       2
# 5    758       运动头盔       头盔  辅助用品       4
# 6    711    公路自行车车架  公路自行车车架    配件       3
# 7    752    山地自行车袜子       袜子    服装       2
# 8    750    山地自行车前轮       车轮    配件       3
# 9    744    山地自行车车把       车把    配件       3
# 10   748    山地自行车后轮       车轮    配件       3
# 11   734     男士运动短裤       短裤    服装       2
# 12   735      女士紧身衣      紧身衣    服装       2
# ...

# %%
# !pip install xlrd -i https://pypi.douban.com/simple/   # 读取表格
# Out:
# Looking in indexes: https://pypi.douban.com/simple/
# ...

# %%
# !pip install openpyxl -i https://pypi.douban.com/simple # 读取表格

# %% [markdown]
# 读取sqlite文件

# %% [markdown]
# 导包sqlite3

# %% [markdown]
# 读取table
#  pd.read_sql("sql语句", con)

# %% [markdown]
# 设置行索引index_col

# %% [markdown]
# 写入sql文件

# %%
import pymysql

# %%
conn = pymysql.connect(user='root', password='201314', host='127.0.0.1', database='data', port=3306)
conn

# %%
# 读数据
df = pd.read_sql('select update_time, confirm, city from details', conn)

# %%
df
# Out:
#             update_time  confirm   city
# 0   2021-04-12 19:40:34    11594  地区待确认
# 1   2021-04-12 19:40:34       91    德宏州
# 2   2021-04-12 19:40:34       63   境外输入
# 3   2021-04-12 19:40:34       25    昭通市
# 4   2021-04-12 19:40:34       53     昆明
# ..                  ...      ...    ...
# 919 2021-04-13 10:28:02        5     鹤岗
# 920 2021-04-13 10:28:02       17    七台河
# 921 2021-04-13 10:28:02       46     鸡西
# 922 2021-04-13 10:28:02        1     伊春
# 923 2021-04-13 10:28:02       15    佳木斯
#
# [924 rows x 3 columns]

# %%
df.sort_values(by=['update_time','confirm'],ascending=False, inplace=True)

# %%
df
# Out:
#             update_time  confirm   city
# 707 2021-04-13 10:28:02    50340     武汉
# 462 2021-04-13 10:28:02    11594  地区待确认
# 711 2021-04-13 10:28:02     3518     孝感
# 715 2021-04-13 10:28:02     2907     黄冈
# 709 2021-04-13 10:28:02     1580     荆州
# ..                  ...      ...    ...
# 168 2021-04-12 19:40:34        0  地区待确认
# 325 2021-04-12 19:40:34        0  地区待确认
# 95  2021-04-12 19:40:34        0  地区待确认
# 47  2021-04-12 19:40:34        0  地区待确认
# 293 2021-04-12 19:40:34        0  地区待确认
#
# [924 rows x 3 columns]

# %% [markdown]
# 根据url获取网络上的数据
