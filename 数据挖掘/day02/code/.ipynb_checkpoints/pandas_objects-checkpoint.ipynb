# %% [markdown]
# 将鱼图像数据进行操作，使用numpy知识

# %%
import matplotlib.pyplot as plt

# %%
fish = plt.imread('./fish.png')

# %% [markdown]
# #### 上下颠倒

# %%
plt.imshow(fish[::-1])

# %% [markdown]
# #### 左右颠倒

# %%
plt.imshow(fish[:,::-1])

# %% [markdown]
# #### 颜色颠倒

# %%
plt.imshow(fish[:, :, ::-1])

# %% [markdown]
# #### 降低精度

# %%
# 每隔4个像素取一个像素点,生成新的图片
plt.imshow(fish[::10, ::10])

# %% [markdown]
# #### 打马赛克

# %%
plt.imshow(fish)

# %%
fish[50:100, 50:100] = 0

# %%
plt.imshow(fish)

# %% [markdown]
# # Pandas的数据结构

# %%
# Series, DataFrame

# %% [markdown]
# 导入pandas：
# 三剑客

# %% [markdown]
# ### 1、Series

# %% [markdown]
# Series是一种类似于一维数组的对象，由下面两个部分组成：
# - values：一组数据（ndarray类型）
# - index：相关的数据索引标签

# %% [markdown]
# #### 1）Series的创建

# %% [markdown]
# 两种创建方式：
#
# (1) 由列表或numpy数组创建
#
#     默认索引为0到N-1的整数型索引

# %%
from pandas import Series
import numpy as np

# %%
l = [1, 2, 3, 4]
# 如果由列表创建series,那么传递的是复制
s = Series(data = l, name='hello', index=list('abcd'))
# series的索引如果不写, 系统默认给一个索引, 从0开始的
s
# Out:
# a    1
# b    2
# c    3
# d    4
# Name: hello, dtype: int64

# %%
s['a'] = 2

# %%
l
# Out:
# [1, 2, 3, 4]

# %%
s
# Out:
# a    2
# b    2
# c    3
# d    4
# Name: hello, dtype: int64

# %%
n = np.array(l)
# 如果由ndarry对象创建series, name传递的是引用
s2 = Series(data = n, name='hello', index=list('abcd'))

# %%
s2 ['a'] = 2

# %%
s2
# Out:
# a    2
# b    2
# c    3
# d    4
# Name: hello, dtype: int32

# %%
n
# Out:
# array([2, 2, 3, 4])

# %% [markdown]
#     还可以通过设置index参数指定索引

# %% [markdown]
# 特别地，由ndarray创建的是引用，而不是副本。对Series元素的改变也会改变原来的ndarray对象中的元素。（列表没有这种情况）

# %% [markdown]
# (2) 由字典创建

# %%
# 字典的key相当于index
s = Series({'a': 1, 'b': 2, 'c':3, 'd':4})

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %% [markdown]
# ============================================
#
# 练习1：
#
# 使用多种方法创建以下Series，命名为s1：
# 语文 150
# 数学 150
# 英语 150
# 理综 300
#
# ============================================

# %%
s = Series({'语文': 150, '数学': 150, '英语':150, '理综':300})

# %%
s
# Out:
# 语文    150
# 数学    150
# 英语    150
# 理综    150
# dtype: int64

# %%
s = Series(data=[150, 150, 150, 300], index=['语文','数学','英语','理综'])

# %%
s
# Out:
# 语文    150
# 数学    150
# 英语    150
# 理综    150
# dtype: int64

# %% [markdown]
# #### 2）Series的索引和切片

# %% [markdown]
# 可以使用中括号取单个索引（此时返回的是元素类型），或者中括号里一个列表取多个索引（此时返回的仍然是一个Series类型）。分为显示索引和隐式索引：
#
# (1) 显式索引：
#
#     - 使用index中的元素作为索引值
#     - 使用.loc[]（推荐）
#
#  注意，此时是闭区间

# %%
# 推荐写法
s.loc['a']
# Out:
# 1

# %%
# 不推荐写法,直接使用中括号
s['a']
# Out:
# 1

# %%
s.loc['a':'c']
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %% [markdown]
# (2) 隐式索引：
#
#     - 使用整数作为索引值
#     - 使用.iloc[]（推荐）
#
#  注意，此时是半开区间

# %%
# i invisible 看不见的索引
s.iloc[0]
# Out:
# 1

# %%
s.iloc[0:3]
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
# 直接使用中括号, 不推荐
s[0]
# Out:
# 1

# %%
#  高级写法, 再加一层中括号, 会返回Series
s.loc[['数学']]
# Out:
# 数学    150
# dtype: int64

# %%
s.values
# Out:
# array([150, 150, 150, 300], dtype=int64)

# %% [markdown]
# ============================================
#
# 练习2：
#
# 使用多种方法对练习1创建的Series s1进行索引和切片：
#
# 索引：
# 数学 150
#
# 切片：
# 语文 150
# 数学 150
# 英语 150
#
# ============================================

# %%
s = Series(data=[150, 150, 150, 300], index=['语文','数学','英语','理综'])

# %%
s
# Out:
# 语文    150
# 数学    150
# 英语    150
# 理综    300
# dtype: int64

# %%
s.loc['数学']
# Out:
# 150

# %%
s.iloc[1]
# Out:
# 150

# %%
s.loc['语文':'英语']
# Out:
# 语文    150
# 数学    150
# 英语    150
# dtype: int64

# %%
s.iloc[0:3]
# Out:
# 语文    150
# 数学    150
# 英语    150
# dtype: int64

# %% [markdown]
# #### 3）Series的基本概念

# %% [markdown]
# 可以把Series看成一个定长的有序字典

# %% [markdown]
# 可以通过shape，size，index,values等得到series的属性

# %%
s.shape
# Out:
# (4,)

# %%
s.size
# Out:
# 4

# %%
s.index
# Out:
# Index(['语文', '数学', '英语', '理综'], dtype='object')

# %%
s.values
# Out:
# array([150, 150, 150, 300], dtype=int64)

# %% [markdown]
# 可以通过head(),tail()快速查看Series对象的样式

# %%
s.head(2)
# Out:
# 语文    150
# 数学    150
# dtype: int64

# %%
s.tail(2)
# Out:
# 英语    150
# 理综    300
# dtype: int64

# %% [markdown]
# 当索引没有对应的值时，可能出现缺失数据显示NaN（not a number）的情况

# %% [markdown]
# 可以使用pd.isnull()，pd.notnull()，或自带isnull(),notnull()函数检测缺失数据

# %% [markdown]
# Series对象本身及其实例都有一个name属性

# %% [markdown]
# #### 4）Series的运算

# %% [markdown]
# (1) 适用于numpy的数组运算也适用于Series

# %% [markdown]
# (2) Series之间的运算
#
# - 在运算中自动对齐不同索引的数据
# - 如果索引不对应，则补NaN

# %%
# series和series之间的运算, 相同索引的元素进行运算, 索引不同的位置补NAN
s1 = Series(data=np.random.randint(0, 10, size=5), index=list('abcde'))
s2 = Series(data=np.random.randint(0, 10, size=5), index=list('bcdef'))
display(s1, s2)
# Out:
# a    4
# b    6
# c    0
# d    5
# e    6
# dtype: int32
# b    1
# c    5
# d    9
# e    7
# f    7
# dtype: int32

# %%
s1 + s2
# Out:
# a     NaN
# b     7.0
# c     5.0
# d    14.0
# e    13.0
# f     NaN
# dtype: float64

# %% [markdown]
# - 注意：要想保留所有的index，则需要使用.add()函数

# %%
s1.add(s2, fill_value=0)
# Out:
# a     4.0
# b     7.0
# c     5.0
# d    14.0
# e    13.0
# f     7.0
# dtype: float64

# %% [markdown]
# ============================================
#
# 练习3：
#
# 1. 想一想Series运算和ndarray运算的规则有什么不同？
#
# 2. 新建另一个索引包含“文综”的Series s2，并与s2进行多种算术操作。思考如何保存所有数据。
#
# ============================================

# %%
Series没有广播机制,nadarray有广播机制

# %%
s1 = Series(data=[150, 150, 150, 300], index=['语文','数学','英语','文综'])
s2 = Series(data=[150, 150, 150, 300], index=['语文','数学','英语','理综'])
display(s1, s2)
# Out:
# 语文    150
# 数学    150
# 英语    150
# 文综    300
# dtype: int64
# 语文    150
# 数学    150
# 英语    150
# 理综    300
# dtype: int64

# %%
s1 + s2
# Out:
# 数学    300.0
# 文综      NaN
# 理综      NaN
# 英语    300.0
# 语文    300.0
# dtype: float64

# %%
s1.add(s2, fill_value=0)/2
# Out:
# 数学    150.0
# 文综    150.0
# 理综    150.0
# 英语    150.0
# 语文    150.0
# dtype: float64

# %% [markdown]
# ### 2、DataFrame

# %% [raw]
# DataFrame是一个【表格型】的数据结构，可以看做是【由Series组成的字典】（共用同一个索引）。DataFrame由按一定顺序排列的多列数据组成。设计初衷是将Series的使用场景从一维拓展到二维。DataFrame既有行索引，也有列索引。
# - 行索引：index
# - 列索引：columns
# - 值：values（numpy的二维数组）

# %% [markdown]
# #### 1）DataFrame的创建
# 最常用的方法是传递一个字典来创建。DataFrame以字典的键作为每一【列】的名称，以字典的值（一个数组）作为每一列。
#
# 此外，DataFrame会自动加上每一行的索引（和Series一样）。
#
# 同Series一样，若传入的列与字典的键不匹配，则相应的值为NaN。

# %%
from pandas import DataFrame

# %%
# 关键字写法
# data要求是二维的ndarray
index = ['张三', '李四', '王五', '赵六']
columns = ['语文', '数学', '英语', 'Python']
data  = np.random.randint(0, 150, size=(4, 4))
df = DataFrame(index=index, columns=columns, data=data)
df
# Out:
#      语文   数学   英语  Python
# 张三   14  104   36     103
# 李四  145   35  140       3
# 王五   15   20   74      47
# 赵六   47   29   85      54

# %%
# 字典的创建方式
# 字典的key是columns, 字典的value是每一列的值,必须一维
df = DataFrame({'语文': np.random.randint(0, 150, size=4), '语文': np.random.randint(0, 150, size=4), '数学': np.random.randint(0, 150, size=4), '英语': np.random.randint(0, 150, size=4),'Python': np.random.randint(0, 150, size=4)},index=['张三', '李四', '王五', '赵六'])
df
# Out:
#      语文   数学   英语  Python
# 张三  128   92   42      19
# 李四   35   98  116      31
# 王五   63   81   75       5
# 赵六   68  117   11      52

# %% [markdown]
# DataFrame属性：values、columns、index、shape

# %% [markdown]
# ============================================
#
# 练习4：
#
# 根据以下考试成绩表，创建一个DataFrame，命名为df：
# ```
#     张三  李四
# 语文 150  0
# 数学 150  0
# 英语 150  0
# 理综 300  0
# ```
#
# ============================================

# %%
columns = ['张三', '李四']
index = ['语文', '数学', '英语', '理综']
data  = np.random.randint(0, 150, size=(4, 2))
df = DataFrame(index=index, columns=columns, data=data)
df
# Out:
#      张三  李四
# 语文   38   0
# 数学   84  69
# 英语  100  33
# 理综  101  69

# %% [markdown]
# #### 2）DataFrame的索引

# %% [markdown]
# (1) 对列进行索引
#
#     - 通过类似字典的方式
#     - 通过属性的方式
#
#  可以将DataFrame的列获取为一个Series。返回的Series拥有原DataFrame相同的索引，且name属性也已经设置好了，就是相应的列名。

# %%
# 通过属性的方式, 把列名当成是dataframe的一个属性
df.语文
# Out:
# 张三     14
# 李四    145
# 王五     15
# 赵六     47
# Name: 语文, dtype: int32

# %%
# 推荐写法, 列索引
df['语文']
# Out:
# 张三     14
# 李四    145
# 王五     15
# 赵六     47
# Name: 语文, dtype: int32

# %%
# 如果想反悔DataFrame
df[['语文']]
# Out:
#      语文
# 张三   14
# 李四  145
# 王五   15
# 赵六   47

# %%
df['计算机'] = np.random.randint(0, 150, size=4)

# %%
df
# Out:
#      语文   数学   英语  Python  计算机
# 张三  128   92   42      19  109
# 李四   35   98  116      31   48
# 王五   63   81   75       5   73
# 赵六   68  117   11      52   22

# %% [markdown]
# (2) 对行进行索引
#
#     - 使用.loc[]加index来进行行索引
#     - 使用.iloc[]加整数来进行行索引
#
#  同样返回一个Series，index为原来的columns。

# %%
# 显示索引和隐式索引
df.loc[['张三', '李四']]
# Out:
#      语文   数学   英语  Python  计算机
# 张三   14  104   36     103  122
# 李四  145   35  140       3   90

# %%
df.iloc[[0,1]]
# Out:
#      语文   数学   英语  Python  计算机
# 张三   14  104   36     103  122
# 李四  145   35  140       3   90

# %%
# 如果列想用隐式索引,就必须从行开始写,先行后列
df.iloc[:, [0]]
# Out:
#      语文
# 张三   14
# 李四  145
# 王五   15
# 赵六   47

# %% [markdown]
# (3) 对元素索引的方法
#     - 使用列索引
#     - 使用行索引(iloc[3,1]相当于两个参数;iloc[[3,3]] 里面的[3,3]看做一个参数)
#     - 使用values属性（二维numpy数组）

# %%
# 元素索引,永远都是先行后列
df.loc[['张三'], ['英语']]
# Out:
#     英语
# 张三  42

# %%
# 隐式写法
df.iloc[0,2]
# Out:
# 42

# %% [markdown]
# 【注意】
# 直接用中括号时：
# - 索引表示的是列索引
# - 切片表示的是行切片

# %%
# 列切片
df.loc[:, '语文':'英语']
# Out:
#      语文   数学   英语
# 张三  128   92   42
# 李四   35   98  116
# 王五   63   81   75
# 赵六   68  117   11

# %%
# 直接中括号的切片,切的是行 不推荐!!!
df['张三':'王五']
# Out:
#      语文  数学   英语  Python
# 张三  128  92   42      19
# 李四   35  98  116      31
# 王五   63  81   75       5

# %%
# 行切片
df.loc['张三':'王五']
# Out:
#      语文  数学   英语  Python
# 张三  128  92   42      19
# 李四   35  98  116      31
# 王五   63  81   75       5

# %% [markdown]
# ============================================
#
# 练习5：
#
# 使用多种方法对ddd进行索引和切片，并比较其中的区别
#
# ============================================

# %%
df
# Out:
#      语文   数学   英语  Python  计算机
# 张三  128   92   42      19  109
# 李四   35   98  116      31   48
# 王五   63   81   75       5   73
# 赵六   68  117   11      52   22

# %%
# 1.找Python这一列成绩使用多种写法
df.loc[:,'Python':'Python']
df.iloc[:, 3:4]
df.loc[:, ['Python']]
df.iloc[:, [3]]
df[['Python']]
df.Python
# Out:
# 张三    19
# 李四    31
# 王五     5
# 赵六    52
# Name: Python, dtype: int32

# %%
# 2.找到李四的成绩
df.loc[['李四']]
# Out:
#     语文  数学   英语  Python  计算机
# 李四  35  98  116      31   48

# %%
# 切数学到Python的成绩
df.loc[:,'数学':'Python']
# Out:
#      数学   英语  Python
# 张三   92   42      19
# 李四   98  116      31
# 王五   81   75       5
# 赵六  117   11      52

# %%
# 切李四到赵六的成绩
df.loc['李四':'赵六']
# Out:
#     语文   数学   英语  Python  计算机
# 李四  35   98  116      31   48
# 王五  63   81   75       5   73
# 赵六  68  117   11      52   22

# %%
# 赵六的Python成绩, 要求返回dataframe
df.loc[['赵六'], ['Python']]
# Out:
#     Python
# 赵六      52

# %% [markdown]
# #### 3）DataFrame的运算

# %% [markdown]
# （1） DataFrame之间的运算
#
# 同Series一样：
#
# - 在运算中自动对齐不同索引的数据
# - 如果索引不对应，则补NaN

# %%
df2 = df.copy()

# %%
df + df2
# Out:
#      语文   数学   英语  Python  计算机
# 张三  256  184   84      38  218
# 李四   70  196  232      62   96
# 王五  126  162  150      10  146
# 赵六  136  234   22     104   44

# %%
df2.index = ['张三', '李四', '老王', '小六子']

# %%
df + df2
# Out:
#         语文     数学     英语  Python    计算机
# 小六子    NaN    NaN    NaN     NaN    NaN
# 张三   256.0  184.0   84.0    38.0  218.0
# 李四    70.0  196.0  232.0    62.0   96.0
# 王五     NaN    NaN    NaN     NaN    NaN
# 老王     NaN    NaN    NaN     NaN    NaN
# 赵六     NaN    NaN    NaN     NaN    NaN

# %%
df.add(df2, fill_value=0)
# Out:
#         语文     数学     英语  Python    计算机
# 小六子   68.0  117.0   11.0    52.0   22.0
# 张三   256.0  184.0   84.0    38.0  218.0
# 李四    70.0  196.0  232.0    62.0   96.0
# 王五    63.0   81.0   75.0     5.0   73.0
# 老王    63.0   81.0   75.0     5.0   73.0
# 赵六    68.0  117.0   11.0    52.0   22.0

# %% [markdown]
# 创建DataFrame df1 不同人员的各科目成绩，月考一

# %%
index = ['张三', '李四', '王五', '赵六']
columns = ['语文', '数学', '英语', 'Python']
data = np.random.randint(1, 150, size=(4, 4))
df1 = DataFrame(index=index, columns=columns, data=data)

# %% [markdown]
# 创建DataFrame df2 不同人员的各科目成绩，月考二
# 有新学生转入

# %% [markdown]
# 下面是Python 操作符与pandas操作函数的对应表：
#
# | Python Operator | Pandas Method(s)                      |
# |-----------------|---------------------------------------|
# | ``+``           | ``add()``                             |
# | ``-``           | ``sub()``, ``subtract()``             |
# | ``*``           | ``mul()``, ``multiply()``             |
# | ``/``           | ``truediv()``, ``div()``, ``divide()``|
# | ``//``          | ``floordiv()``                        |
# | ``%``           | ``mod()``                             |
# | ``**``          | ``pow()``                             |

# %% [markdown]
# （2） Series与DataFrame之间的运算
#
# 【重要】
#
# - 使用Python操作符：以行为单位操作（参数必须是行），对所有行都有效。（类似于numpy中二维数组与一维数组的运算，但可能出现NaN）
#
# - 使用pandas操作函数：
#
#         axis=0：以列为单位操作（参数必须是列），对所有列都有效。
#         axis=1：以行为单位操作（参数必须是行），对所有行都有效。

# %%
# dataframe 和series的运算,默认是比较datafarame的列索引和series的索引是否一致, 一致的地方就会进行运算

# %%
df
# Out:
#      语文   数学   英语  Python  计算机
# 张三  128   92   42      19  109
# 李四   35   98  116      31   48
# 王五   63   81   75       5   73
# 赵六   68  117   11      52   22

# %%
s = Series(index=df.columns, data=np.random.randint(0, 150, size=5))
s
# Out:
# 语文         38
# 数学         30
# 英语        139
# Python     86
# 计算机        63
# dtype: int32

# %%
# 默认操作就是dataframe的每一行和这个series相加
df + s
# Out:
#      语文   数学   英语  Python  计算机
# 张三  166  122  181     105  172
# 李四   73  128  255     117  111
# 王五  101  111  214      91  136
# 赵六  106  147  150     138   85

# %%
s2 = Series(index=df.index, data=np.random.randint(0, 150, size=4))
s2
# Out:
# 张三     20
# 李四     63
# 王五     29
# 赵六    140
# dtype: int32

# %%
# 默认是按照dataframe的列索引进行操作
df + s2
# Out:
#     Python  张三  数学  李四  王五  英语  计算机  语文  赵六
# 张三     NaN NaN NaN NaN NaN NaN  NaN NaN NaN
# 李四     NaN NaN NaN NaN NaN NaN  NaN NaN NaN
# 王五     NaN NaN NaN NaN NaN NaN  NaN NaN NaN
# 赵六     NaN NaN NaN NaN NaN NaN  NaN NaN NaN

# %%
df.add(s2, axis='index')
# Out:
#      语文   数学   英语  Python  计算机
# 张三  148  112   62      39  129
# 李四   98  161  179      94  111
# 王五   92  110  104      34  102
# 赵六  208  257  151     192  162

# %% [markdown]
# ============================================
#
# 练习6：
#
# 1. 假设ddd是期中考试成绩，ddd2是期末考试成绩，请自由创建ddd2，并将其与ddd相加，求期中期末平均值。
#
# 2. 假设张三期中考试数学被发现作弊，要记为0分，如何实现？
#
# 3. 李四因为举报张三作弊立功，期中考试所有科目加100分，如何实现？
#
# 4. 后来老师发现有一道题出错了，为了安抚学生情绪，给每位学生每个科目都加10分，如何实现？
#
# ============================================

# %%
index = ['张三', '李四', '王五', '赵六']
columns = ['语文', '数学', '英语', 'Python']
data = np.random.randint(1, 150, size=(4, 4))
ddd = DataFrame(index=index, columns=columns, data=data)

# %%
data = np.random.randint(1, 150, size=(4, 4))
ddd2 = DataFrame(index=index, columns=columns, data=data)

# %%
# 1.求期中期末平均值
avg = ddd.add(ddd2, fill_value=0)
avg.div(2)
# Out:
#        语文    数学     英语  Python
# 张三   30.5  65.0  100.5    65.0
# 李四   75.0  57.0   25.5   121.5
# 王五  105.0  37.0  120.0    36.5
# 赵六   75.0  62.0   40.0    82.0

# %%
# 2.假设张三期中考试数学被发现作弊，要记为0分，如何实现？
ddd.loc['张三','语文'] = 0
ddd
# Out:
#      语文  数学   英语  Python
# 张三    0  67  122     103
# 李四  134  28   25     120
# 王五  121  26  149      66
# 赵六   98  69   50      21

# %%
ddd.loc['李四'] += 100

# %%
ddd
# Out:
#      语文   数学   英语  Python
# 张三    0   67  122     103
# 李四  234  128  125     220
# 王五  121   26  149      66
# 赵六   98   69   50      21

# %%
ddd.loc[:] += 10

# %%
ddd
# Out:
#      语文   数学   英语  Python
# 张三   10   77  132     113
# 李四  244  138  135     230
# 王五  131   36  159      76
# 赵六  108   79   60      31
